# %% [markdown]
# # Criação de gráficos a partir de dados presentes na base de dados

# %%
# %load_ext sql

# %%
import os

user = os.getenv('postgres')
password = os.getenv('1234')
connection_string = "postgresql://postgres:1234@localhost/mapa".format(user=user, password=password)
# %sql $connection_string
# Out:
# 'Connected: postgres@mapa'

# %%
from IPython.core.display import HTML, SVG
import pandas as pd
import numpy as np
import IPython 
from ipywidgets import Layout
from ipywidgets import widgets
from IPython.display import display

# %%
result = %sql SELECT nofcases, "country/region" FROM covid_by_date
# %matplotlib inline
result.pie()
# Out:
#  * postgresql://postgres:***@localhost/mapa
# 12768 rows affected.
# ([<matplotlib.patches.Wedge at 0x1bf4fe98e10>,
# ...
#   ...],
#  [Text(1.0999999294967444, 0.0003938364604555832, 'Mainland China'),
#   Text(1.099999302747659, 0.0012385292343234044, 'Mainland China'),
#   Text(1.0999977387524484, 0.00223041240592545, 'Mainland China'),
#   Text(1.0999947208721117, 0.003407939771355682, 'Mainland China'),
#   Text(1.0999897561864158, 0.004747239718976298, 'Mainland China'),
#   Text(1.0999823365463623, 0.00623372168175375, 'Mainland China'),
#   Text(1.0999716371667898, 0.007899204302485894, 'Mainland China'),
#   Text(1.0999567626778881, 0.009752960534130046, 'Mainland China'),
#   Text(1.09993715864161, 0.011757850119052336, 'Mainland China'),
#   Text(1.0999095836465402, 0.014103467747143793, 'Mainland China'),
#   Text(1.0998727870669551, 0.016728785657319875, 'Mainland China'),
#   Text(1.0998297242592971, 0.01935400825975897, 'Mainland China'),
# ...

# %%
result = %sql SELECT nofcases, "country/region" FROM covid_by_date WHERE nofcases > 10000
# %matplotlib inline
result.pie()
# Out:
#  * postgresql://postgres:***@localhost/mapa
# 37 rows affected.
# ([<matplotlib.patches.Wedge at 0x1bf4d3be240>,
# ...
#  [Text(1.099815311652202, 0.02015639490012193, 'Mainland China'),
#   Text(1.0980976783116425, 0.06466443293326314, 'Mainland China'),
#   Text(1.0935514237317263, 0.11893394660194656, 'Mainland China'),
#   Text(1.084528176947828, 0.1838440464258235, 'Mainland China'),
#   Text(1.0694026473436729, 0.25763923974104674, 'Mainland China'),
#   Text(1.046359558250164, 0.339310587601569, 'Mainland China'),
#   Text(1.0136289274900327, 0.42726619027885443, 'Mainland China'),
#   Text(0.9695638336137601, 0.5195632517299402, 'Mainland China'),
#   Text(0.8755526764947028, 0.6658885122022774, 'Mainland China'),
#   Text(0.7093740433395059, 0.8407071229840752, 'Mainland China'),
#   Text(0.5085929911071205, 0.9753630961835252, 'Mainland China'),
#   Text(0.2828468528271555, 1.0630134796162152, 'Mainland China'),
# ...

# %%
result = %sql SELECT nofcases, "country/region" FROM covid_by_date WHERE "country/region" = 'Portugal'
# %matplotlib inline
result.pie()
# Out:
#  * postgresql://postgres:***@localhost/mapa
# 48 rows affected.
# ([<matplotlib.patches.Wedge at 0x1bf5e9cdf28>,
# ...
#  [Text(1.1, 0.0, 'Portugal'),
#   Text(1.1, 0.0, 'Portugal'),
#   Text(1.1, 0.0, 'Portugal'),
#   Text(1.1, 0.0, 'Portugal'),
#   Text(1.1, 0.0, 'Portugal'),
#   Text(1.1, 0.0, 'Portugal'),
#   Text(1.1, 0.0, 'Portugal'),
#   Text(1.1, 0.0, 'Portugal'),
#   Text(1.1, 0.0, 'Portugal'),
#   Text(1.1, 0.0, 'Portugal'),
#   Text(1.0982060144323316, 0.06279768996272098, 'Portugal'),
#   Text(1.0838892204502593, 0.18757440601459904, 'Portugal'),
#   Text(1.0250504333214954, 0.39908847283204585, 'Portugal'),
#   Text(0.8104152560956099, 0.7437923854729135, 'Portugal'),
#   Text(0.24914646149512057, 1.071413104607397, 'Portugal'),
#   Text(-0.720346805570854, 0.8313245333224966, 'Portugal'),
#   Text(-0.9253788620705365, -0.5947049366139809, 'Portugal'),
#   Text(0.7203468834050711, -0.8313244658787573, 'Portugal'),
#   Text(1.0999999999999925, 1.2873679038053e-07, 'Portugal'),
# ...

# %%
# %sql SELECT COUNT(nofcases), "country/region" FROM covid_by_date GROUP BY "country/region" ORDER BY COUNT(nofcases)
# Out:
#  * postgresql://postgres:***@localhost/mapa
# 111 rows affected.
# [(48, 'Andorra'),
#  (48, 'Faroe Islands'),
#  (48, 'Indonesia'),
#  (48, 'Italy'),
#  (48, 'Gibraltar'),
#  (48, 'Thailand'),
#  (48, 'Togo'),
#  (48, 'Bangladesh'),
#  (48, 'Oman'),
#  (48, 'Cameroon'),
#  (48, 'Luxembourg'),
#  (48, 'Czech Republic'),
#  (48, 'Others'),
#  (48, 'Sweden'),
#  (48, 'Jordan'),
#  (48, 'Dominican Republic'),
#  (48, 'Ireland'),
#  (48, 'Germany'),
#  (48, 'Cambodia'),
#  (48, 'Singapore'),
#  (48, 'San Marino'),
#  (48, 'Sri Lanka'),
#  (48, 'Brunei'),
#  (48, 'Portugal'),
#  (48, 'Finland'),
#  (48, 'South Korea'),
#  (48, 'Malta'),
#  (48, 'Colombia'),
#  (48, 'Albania'),
#  (48, 'Ukraine'),
#  (48, 'Saudi Arabia'),
#  (48, 'Argentina'),
#  (48, 'Liechtenstein'),
#  (48, 'Macau'),
#  (48, 'Latvia'),
#  (48, 'Slovenia'),
#  (48, 'Azerbaijan'),
#  (48, 'Greece'),
#  (48, 'Egypt'),
#  (48, 'Afghanistan'),
#  (48, 'India'),
#  (48, 'Iran'),
#  (48, 'Chile'),
#  (48, 'Algeria'),
# ...

# %%
result = %sql SELECT COUNT(nofcases), "country/region" FROM covid_by_date GROUP BY "country/region" ORDER BY COUNT(nofcases)
# %matplotlib inline

result.pie()
# Out:
#  * postgresql://postgres:***@localhost/mapa
# 111 rows affected.
# ([<matplotlib.patches.Wedge at 0x1bf5f5a5cf8>,
# ...
#  [Text(1.0999232825541922, 0.012991246868981803, 'Andorra'),
#   Text(1.0993096071924164, 0.03896649245768928, 'Faroe Islands'),
#   Text(1.098082598854062, 0.06491999764255645, 'Indonesia'),
#   Text(1.0962429421184967, 0.09083728229852703, 'Italy'),
#   Text(1.0937916633773166, 0.11670388650890522, 'Gibraltar'),
#   Text(1.0907301302616932, 0.1425053786329135, 'Thailand'),
#   Text(1.0870600508793395, 0.16822736335747435, 'Togo'),
#   Text(1.082783472861512, 0.19385548972872418, 'Bangladesh'),
#   Text(1.077902782220584, 0.21937545915877787, 'Oman'),
#   Text(1.0724207020188292, 0.24477303340327702, 'Cameroon'),
#   Text(1.0663402908491555, 0.2700340425052711, 'Luxembourg'),
#   Text(1.0596649411286374, 0.29514439270099907, 'Czech Republic'),
#   Text(1.0523983772057997, 0.32009007428316133, 'Others'),
#   Text(1.0445446532827076, 0.3448571694172939, 'Sweden'),
# ...

# %%
result = %sql SELECT COUNT(nofcases), "country/region" FROM covid_by_date GROUP BY "country/region" ORDER BY COUNT(nofcases)
# %matplotlib inline

result.bar()
# Out:
#  * postgresql://postgres:***@localhost/mapa
# 111 rows affected.
# <BarContainer object of 111 artists>

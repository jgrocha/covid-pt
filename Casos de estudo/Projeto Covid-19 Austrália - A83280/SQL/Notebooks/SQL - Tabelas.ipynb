# %% [markdown]
# # Estabelecimento de uma ligação à base de dados e criação de tabelas com dados da base de dados

# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['Requirement already satisfied: ipython-sql in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (0.3.9)',
#  'Requirement already satisfied: prettytable in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (0.7.2)',
#  'Requirement already satisfied: sqlparse in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (0.3.1)',
#  'Requirement already satisfied: ipython>=1.0 in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (7.13.0)',
#  'Requirement already satisfied: six in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (1.14.0)',
#  'Requirement already satisfied: ipython-genutils>=0.1.0 in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (0.2.0)',
#  'Requirement already satisfied: sqlalchemy>=0.6.7 in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (1.3.16)',
# ...

# %%
# %load_ext sql

# %%
# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
import os

user = os.getenv('postgres')
password = os.getenv('1234')
connection_string = "postgresql://postgres:1234@localhost/mapa".format(user=user, password=password)
# %sql $connection_string
# Out:
# 'Connected: postgres@mapa'

# %%
# %%sql postgresql://postgres:1234@localhost/mapa
# select freguesia from braga
# Out:
# 37 rows affected.
# [('União das freguesias de Guisande e Oliveira (São Pedro)',),
#  ('Tebosa',),
#  ('União das freguesias de Escudeiros e Penso (Santo Estêvão e São Vicente)',),
#  ('Lamas',),
#  ('Priscos',),
#  ('Ruilhe',),
#  ('União das freguesias de Morreira e Trandeiras',),
#  ('União das freguesias de Arentim e Cunha',),
#  ('Figueiredo',),
#  ('Esporões',),
#  ('União das freguesias de Vilaça e Fradelos',),
#  ('Tadim',),
#  ('União das freguesias de Celeirós, Aveleda e Vimieiro',),
#  ('União das freguesias de Cabreiros e Passos (São Julião)',),
#  ('União das freguesias de Lomar e Arcos',),
#  ('União das freguesias de Nogueiró e Tenões',),
#  ('Sequeira',),
#  ('Padim da Graça',),
#  ('Sobreposta',),
#  ('União das freguesias de Ferreiros e Gondizalves',),
#  ('União das freguesias de Nogueira, Fraião e Lamaçães',),
#  ('Gualtar',),
#  ('União das freguesias de Braga (São José de São Lázaro e São João do Souto)',),
#  ('Mire de Tibães',),
# ...

# %%
# %%sql postgresql://postgres:1234@localhost/mapa
# select freguesia, concelho, distrito from portugal
# Out:
# 3223 rows affected.
# [('Montenegro', 'FARO', 'FARO'),
#  ('Sagres', 'VILA DO BISPO', 'FARO'),
#  ('Sagres', 'VILA DO BISPO', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('São Gonçalo de Lagos', 'LAGOS', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('Pechão', 'OLHÃO', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('Sagres', 'VILA DO BISPO', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
#  ('Albufeira e Olhos de Água', 'ALBUFEIRA', 'FARO'),
# ...

# %%
# %%sql postgresql://postgres:1234@localhost/mapa
# select sovereignt, subregion, continent from world
# Out:
# 255 rows affected.
# [('Indonesia', 'South-Eastern Asia', 'Asia'),
#  ('Malaysia', 'South-Eastern Asia', 'Asia'),
#  ('Chile', 'South America', 'South America'),
#  ('Bolivia', 'South America', 'South America'),
#  ('Peru', 'South America', 'South America'),
#  ('Argentina', 'South America', 'South America'),
#  ('United Kingdom', 'Western Asia', 'Asia'),
#  ('Kenya', 'Eastern Africa', 'Africa'),
#  ('Cyprus', 'Western Asia', 'Asia'),
#  ('India', 'Southern Asia', 'Asia'),
#  ('China', 'Eastern Asia', 'Asia'),
#  ('Pakistan', 'Southern Asia', 'Asia'),
#  ('Israel', 'Western Asia', 'Asia'),
#  ('Libya', 'Northern Africa', 'Africa'),
#  ('Israel', 'Western Asia', 'Asia'),
#  ('Malawi', 'Eastern Africa', 'Africa'),
#  ('United Republic of Tanzania', 'Eastern Africa', 'Africa'),
#  ('Syria', 'Western Asia', 'Asia'),
#  ('Guyana', 'South America', 'South America'),
#  ('South Korea', 'Eastern Asia', 'Asia'),
#  ('Lebanon', 'Western Asia', 'Asia'),
# ...

# %%
# %%sql postgresql://postgres:1234@localhost/mapa
# select id, geom, "country/region", nofcases from covid_by_date
# Out:
# 12768 rows affected.
# [(1, '0101000020E61000001FF46C567D4E5D40A54E401361D33F40', 'Mainland China', 297),
#  (2, '0101000020E61000001FF46C567D4E5D40A54E401361D33F40', 'Mainland China', 340),
#  (3, '0101000020E61000001FF46C567D4E5D40A54E401361D33F40', 'Mainland China', 408),
#  (4, '0101000020E61000001FF46C567D4E5D40A54E401361D33F40', 'Mainland China', 480),
#  (5, '0101000020E61000001FF46C567D4E5D40A54E401361D33F40', 'Mainland China', 530),
#  (6, '0101000020E61000001FF46C567D4E5D40A54E401361D33F40', 'Mainland China', 591),
#  (7, '0101000020E61000001FF46C567D4E5D40A54E401361D33F40', 'Mainland China', 665),
#  (8, '0101000020E61000001FF46C567D4E5D40A54E401361D33F40', 'Mainland China', 733),
#  (9, '0101000020E61000001FF46C567D4E5D40A54E401361D33F40', 'Mainland China', 779),
#  (10, '0101000020E61000001FF46C567D4E5D40A54E401361D33F40', 'Mainland China', 990),
#  (11, '0101000020E61000001FF46C567D4E5D40A54E401361D33F40', 'Mainland China', 990),
# ...

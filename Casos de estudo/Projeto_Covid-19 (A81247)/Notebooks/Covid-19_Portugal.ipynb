# %% [markdown]
# # COVID-19 em Portugal

# %% [markdown]
# - Os dados aqui utilizados foram encontrados em [Git Hub Jgrocha](https://github.com/jgrocha/covid-pt) e foi feito o backup para a base de dados.

# %% [markdown]
# **Conexão Base de dados**

# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['Requirement already satisfied: ipython-sql in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (0.3.9)',
#  'Requirement already satisfied: sqlalchemy>=0.6.7 in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (1.3.16)',
#  'Requirement already satisfied: ipython-genutils>=0.1.0 in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (0.2.0)',
#  'Requirement already satisfied: sqlparse in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (0.3.1)',
#  'Requirement already satisfied: six in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (1.14.0)',
#  'Requirement already satisfied: prettytable in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (0.7.2)',
#  'Requirement already satisfied: ipython>=1.0 in c:\\osgeo4~1\\apps\\python37\\lib\\site-packages (from ipython-sql) (7.13.0)',
# ...

# %%
# !pip install ipython-sql
# !pip install sqlalchemy
# Out:
# ...
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the 'c:\osgeo4~1\bin\python3.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the 'c:\osgeo4~1\bin\python3.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import psycopg2
import sqlalchemy
import matplotlib as plt


# %matplotlib inline

# %%
# %load_ext sql

# %%
from sqlalchemy import create_engine

# %%
# Example format
# %sql postgresql://postgres:1234@localhost/MIEBIOM
# Out:
# 'Connected: postgres@MIEBIOM'

# %%
# Example format
engine = create_engine('postgresql://postgres:1234@localhost/MIEBIOM')

# %%
# %%sql postgresql://postgres:1234@localhost/MIEBIOM
#
# SELECT data_relatorio FROM situacao_epidemiologica
# Out:
# 85 rows affected.
# [(datetime.date(2020, 3, 7),),
#  (datetime.date(2020, 3, 8),),
#  (datetime.date(2020, 3, 10),),
#  (datetime.date(2020, 3, 13),),
#  (datetime.date(2020, 3, 14),),
#  (datetime.date(2020, 3, 16),),
#  (datetime.date(2020, 3, 18),),
#  (datetime.date(2020, 3, 20),),
#  (datetime.date(2020, 3, 21),),
#  (datetime.date(2020, 3, 31),),
#  (datetime.date(2020, 3, 3),),
#  (datetime.date(2020, 4, 26),),
#  (datetime.date(2020, 4, 22),),
#  (datetime.date(2020, 4, 25),),
#  (datetime.date(2020, 5, 3),),
#  (datetime.date(2020, 4, 27),),
#  (datetime.date(2020, 4, 4),),
#  (datetime.date(2020, 3, 9),),
#  (datetime.date(2020, 3, 11),),
#  (datetime.date(2020, 3, 12),),
#  (datetime.date(2020, 3, 15),),
#  (datetime.date(2020, 3, 17),),
#  (datetime.date(2020, 3, 27),),
#  (datetime.date(2020, 3, 28),),
#  (datetime.date(2020, 3, 29),),
#  (datetime.date(2020, 3, 30),),
#  (datetime.date(2020, 4, 1),),
#  (datetime.date(2020, 4, 2),),
#  (datetime.date(2020, 4, 3),),
# ...

# %%
casos = %sql SELECT data_relatorio, confirmados, recuperados, obitos, suspeitos, aguarda_resultados, em_vigilancia FROM situacao_epidemiologica ORDER BY data_relatorio

casos
# Out:
#  * postgresql://postgres:***@localhost/MIEBIOM
# 85 rows affected.
# [(datetime.date(2020, 3, 3), 4, None, 0, 101, None, None),
#  (datetime.date(2020, 3, 4), 6, None, 0, 117, None, 81),
#  (datetime.date(2020, 3, 5), 9, None, 0, 147, None, 213),
#  (datetime.date(2020, 3, 6), 13, None, 0, 181, 30, 354),
#  (datetime.date(2020, 3, 7), 21, None, 0, 224, 47, 412),
#  (datetime.date(2020, 3, 8), 30, None, 0, 281, 56, 447),
#  (datetime.date(2020, 3, 9), 39, None, 0, 339, 67, 496),
#  (datetime.date(2020, 3, 10), 41, None, 0, 375, 83, 667),
#  (datetime.date(2020, 3, 11), 59, None, 0, 471, 83, 3066),
#  (datetime.date(2020, 3, 12), 78, None, 0, 637, 133, 4923),
#  (datetime.date(2020, 3, 13), 112, None, 0, 1308, 172, 5674),
#  (datetime.date(2020, 3, 14), 169, 1, 0, 1704, 126, 5011),
#  (datetime.date(2020, 3, 15), 245, 2, 0, 2271, 281, 4592),
#  (datetime.date(2020, 3, 16), 331, 3, 0, 2908, 374, 4592),
#  (datetime.date(2020, 3, 17), 448, 3, 0, 4030, 323, 6852),
# ...

# %%
df = pd.DataFrame(data=casos)

x = df[0]
y1 = df[1]
y2 = df[2]
y3 = df[3]
y4 = df[4]
y5 = df[5]
y6 = df[6]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Situação Epidemiológica

# %%
plt=__import__("matplotlib.pyplot")
fig, ax = plt.pyplot.subplots(figsize=(30,10))




# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
ax.plot(x, y1, label='Confirmados')  # Plot some data on the axes.
ax.plot(x, y2, label='Recuperados')  # Plot more data on the axes...
ax.plot(x, y3, label='Óbitos')# ... and some more.
ax.plot(x, y4, label='Suspeitos')
ax.plot(x, y5, label='Aguarda Resultados')
ax.plot(x, y6, label='Em Vigilância')
ax.set_xlabel('Data')  # Add an x-label to the axes.
ax.set_ylabel('Nº de Casos')  # Add a y-label to the axes.
ax.set_title("Situação Epidemiológica")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %% [markdown]
# # Idades nos casos confirmados

# %% [markdown]
# ## Sexo Masculino

# %%
confirmados_masculino = %sql SELECT confirmados_masculino_0_9, confirmados_masculino_10_19, confirmados_masculino_20_29, confirmados_masculino_30_39, confirmados_masculino_40_49, confirmados_masculino_50_59, confirmados_masculino_60_69, confirmados_masculino_70_79, confirmados_masculino_80_sup FROM situacao_epidemiologica WHERE data_relatorio = '2020-05-18'

confirmados_masculino
# Out:
#  * postgresql://postgres:***@localhost/MIEBIOM
# 1 rows affected.
# [(269, 429, 1600, 1832, 1977, 1957, 1509, 1132, 1409)]

# %%
df1 = pd.DataFrame(data=confirmados_masculino)

df1_transposed = df1.T 

# Criar index 
index = ['confirmados_masculino_0_9', 'confirmados_masculino_10_19', 'confirmados_masculino_20_29', 'confirmados_masculino_30_39', 'confirmados_masculino_40_49', 'confirmados_masculino_50_59', 'confirmados_masculino_60_69', 'confirmados_masculino_70_79', 'confirmados_masculino_80_sup']
df1_transposed.index = index

# Criar coluna
columns = ['nº de confirmados']
df1_transposed.columns = columns

df1_transposed
# Out:
#                               nº de confirmados
# confirmados_masculino_0_9                   269
# confirmados_masculino_10_19                 429
# confirmados_masculino_20_29                1600
# confirmados_masculino_30_39                1832
# confirmados_masculino_40_49                1977
# confirmados_masculino_50_59                1957
# confirmados_masculino_60_69                1509
# confirmados_masculino_70_79                1132
# confirmados_masculino_80_sup               1409

# %%
df1_transposed.plot.bar(y='nº de confirmados', figsize=(5, 5))

# %% [markdown]
# ## Sexo Feminino

# %%
confirmados_feminino = %sql SELECT confirmados_feminino_0_9, confirmados_feminino_10_19, confirmados_feminino_20_29, confirmados_feminino_30_39, confirmados_feminino_40_49, confirmados_feminino_50_59, confirmados_feminino_60_69, confirmados_feminino_70_79, confirmados_feminino_80_sup FROM situacao_epidemiologica WHERE data_relatorio = '2020-05-18'

confirmados_feminino
# Out:
#  * postgresql://postgres:***@localhost/MIEBIOM
# 1 rows affected.
# [(259, 493, 2027, 2431, 2930, 2985, 1741, 1287, 2942)]

# %%
df2 = pd.DataFrame(data=confirmados_feminino)

df2_transposed = df2.T 

# Criar index 
index = ['confirmados_feminino_0_9', 'confirmados_feminino_10_19', 'confirmados_feminino_20_29', 'confirmados_feminino_30_39', 'confirmados_feminino_40_49', 'confirmados_feminino_50_59', 'confirmados_feminino_60_69', 'confirmados_feminino_70_79', 'confirmados_feminino_80_sup']
df2_transposed.index = index

# Criar coluna
columns = ['nº de confirmados']
df2_transposed.columns = columns

df2_transposed
# Out:
#                              nº de confirmados
# confirmados_feminino_0_9                   259
# confirmados_feminino_10_19                 493
# confirmados_feminino_20_29                2027
# confirmados_feminino_30_39                2431
# confirmados_feminino_40_49                2930
# confirmados_feminino_50_59                2985
# confirmados_feminino_60_69                1741
# confirmados_feminino_70_79                1287
# confirmados_feminino_80_sup               2942

# %%
df2_transposed.plot.bar(y='nº de confirmados', figsize=(5, 5))

# %% [markdown]
# # Sintomas

# %%
sintomas = %sql SELECT sintoma_febre, sintoma_tosse, sintoma_respiratoria, sintoma_cefaleia, sintoma_dores, sintoma_fraqueza FROM situacao_epidemiologica WHERE data_relatorio = '2020-05-18' 

sintomas
# Out:
#  * postgresql://postgres:***@localhost/MIEBIOM
# 1 rows affected.
# [(29, 41, 12, 20, 21, 15)]

# %%
df3 = pd.DataFrame(data=sintomas)

df3_transposed = df3.T 

# Criar index 
index = ['sintoma_febre', 'sintoma_tosse', 'sintoma_respiratoria', 'sintoma_cefaleia', 'sintoma_dores', 'sintoma_fraqueza']
df3_transposed.index = index

# Criar coluna
columns = ['Confirmados com sintoma']
df3_transposed.columns = columns

df3_transposed
# Out:
#                       Confirmados com sintoma
# sintoma_febre                              29
# sintoma_tosse                              41
# sintoma_respiratoria                       12
# sintoma_cefaleia                           20
# sintoma_dores                              21
# sintoma_fraqueza                           15

# %%
df3_transposed.plot.pie(y='Confirmados com sintoma', figsize=(10, 10))

# %% [markdown]
# # Confirmados por Distrito

# %%
distritos = %sql SELECT distrito, confirmados_distrito_mais_recente FROM import
distritos
# Out:
#  * postgresql://postgres:***@localhost/MIEBIOM
# 18 rows affected.
# [('AVEIRO', 2162),
#  ('BEJA', 97),
#  ('BRAGA', 2808),
#  ('BRAGANÇA', 230),
#  ('CASTELO BRANCO', 19),
#  ('COIMBRA', 707),
#  ('ÉVORA', 43),
#  ('FARO', 323),
#  ('GUARDA', 181),
#  ('LEIRIA', 248),
#  ('LISBOA', 3894),
#  ('PORTALEGRE', 13),
#  ('PORTO', 8674),
#  ('SANTARÉM', 297),
#  ('SETÚBAL', 751),
#  ('VIANA DO CASTELO', 442),
#  ('VILA REAL', 265),
#  ('VISEU', 462)]

# %%
df = pd.DataFrame(data=distritos)

x = df[1]
y1 = df[0]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcdefaults()
fig, ax = plt.subplots()
y_pos = np.arange(len(y1))

ax.barh(y_pos, x, xerr=y_pos, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(y1)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Número de Casos')
ax.set_title('Casos por Distrito')

plt.show()

# %% [markdown]
# # Confirmados por Concelho

# %% [markdown]
# ## Concelhos com 50 casos ou mais

# %%
concelho = %sql SELECT concelho, mais_recente FROM confirmados_concelho  WHERE mais_recente IS NOT NULL AND mais_recente>=50
concelho
# Out:
#  * postgresql://postgres:***@localhost/MIEBIOM
# 67 rows affected.
# [('PAÇOS DE FERREIRA', 233),
#  ('SANTO TIRSO', 305),
#  ('FARO', 60),
#  ('CONDEIXA-A-NOVA', 68),
#  ('SETÚBAL', 59),
#  ('TROFA', 129),
#  ('VILA NOVA DE GAIA', 1263),
#  ('VILA REAL', 151),
#  ('PORTO', 1211),
#  ('BARREIRO', 89),
#  ('BRAGANÇA', 101),
#  ('CANTANHEDE', 50),
#  ('CASCAIS', 320),
#  ('FELGUEIRAS', 308),
#  ('GONDOMAR', 966),
#  ('MATOSINHOS', 1017),
#  ('FAFE', 79),
#  ('LEIRIA', 64),
#  ('MANGUALDE', 70),
#  ('ESPINHO', 69),
#  ('SÃO JOÃO DA MADEIRA', 57),
#  ('SEIXAL', 160),
#  ('PAREDES', 258),
#  ('PENAFIEL', 142),
#  ('ESTARREJA', 59),
#  ('ÍLHAVO', 108),
#  ('ODIVELAS', 208),
#  ('OEIRAS', 218),
#  ('OLIVEIRA DE AZEMÉIS', 163),
#  ('OVAR', 564),
#  ('MONÇÃO', 68),
#  ('SINTRA', 552),
#  ('BARCELOS', 202),
#  ('COIMBRA', 401),
#  ('SANTARÉM', 73),
#  ('ALBUFEIRA', 68),
#  ('ALMADA', 231),
#  ('ARCOS DE VALDEVEZ', 59),
#  ('MAFRA', 67),
#  ('PESO DA RÉGUA', 52),
# ...

# %%
df = pd.DataFrame(data=concelho)

x = df[1]
y1 = df[0]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcdefaults()
fig, ax = plt.subplots(figsize=(8, 15))
y_pos = np.arange(len(y1))

ax.barh(y_pos, x, xerr=y_pos, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(y1)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Número de Casos')
ax.set_title('Casos por Concelho')

plt.show()

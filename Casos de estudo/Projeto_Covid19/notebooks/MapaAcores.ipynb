# %%
# !pip install geopandas
# !pip install pysal==1.14.4.post2
# Out:
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/83/c5/3cf9cdc39a6f2552922f79915f36b45a95b71fd343cfc51170a5b6ddb6e8/geopandas-0.7.0-py2.py3-none-any.whl (928kB)
#      |████████████████████████████████| 931kB 2.8MB/s
# Collecting fiona
#   Downloading https://files.pythonhosted.org/packages/ec/20/4e63bc5c6e62df889297b382c3ccd4a7a488b00946aaaf81a118158c6f09/Fiona-1.8.13.post1-cp36-cp36m-manylinux1_x86_64.whl (14.7MB)
#      |████████████████████████████████| 14.7MB 300kB/s
# Collecting pyproj>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/e5/c3/071e080230ac4b6c64f1a2e2f9161c9737a2bc7b683d2c90b024825000c0/pyproj-2.6.1.post1-cp36-cp36m-manylinux2010_x86_64.whl (10.9MB)
#      |████████████████████████████████| 10.9MB 43.2MB/s
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.7.0)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.0.3)
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Collecting click-plugins>=1.0
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.12.0)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (7.1.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (19.3.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2018.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (1.18.4)
# Installing collected packages: cligj, munch, click-plugins, fiona, pyproj, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.5.0 fiona-1.8.13.post1 geopandas-0.7.0 munch-2.5.0 pyproj-2.6.1.post1
# Collecting pysal==1.14.4.post2
#   Downloading https://files.pythonhosted.org/packages/e6/e4/c4fb97674458dee71ce8dda517f6ad02c498518d26a0c4b8b692d741c3b9/PySAL-1.14.4.post2.tar.gz (17.9MB)
#      |████████████████████████████████| 17.9MB 1.2MB/s
# Requirement already satisfied: scipy>=0.11 in /usr/local/lib/python3.6/dist-packages (from pysal==1.14.4.post2) (1.4.1)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.6/dist-packages (from pysal==1.14.4.post2) (1.18.4)
# Building wheels for collected packages: pysal
#   Building wheel for pysal (setup.py) ... done
#   Created wheel for pysal: filename=PySAL-1.14.4.post2-py2.py3-none-any.whl size=18106151 sha256=b69df636366b72323e449e520f19d745b19aa9c299de89bc03e99e59ce514d06
#   Stored in directory: /root/.cache/pip/wheels/43/33/20/65692f75cb30834752a6cb566069d5e98ab209392f24bf5466
# Successfully built pysal
# Installing collected packages: pysal
# Successfully installed pysal-1.14.4.post2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# load libraries
# %matplotlib inline
import pandas as pd
from datetime import *
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import seaborn as sns
import time
import os
from pysal.esda.mapclassify import Quantiles, Equal_Interval
import geopandas as gpd
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/pysal/__init__.py:65: VisibleDeprecationWarning: PySAL's API will be changed on 2018-12-31. The last release made with this API is version 1.14.4. A preview of the next API version is provided in the `pysal` 2.0 prelease candidate. The API changes and a guide on how to change imports is provided at https://pysal.org/about
#   ), VisibleDeprecationWarning)

# %%
gdf = gpd.read_file('/content/drive/My Drive/SIG/acores_geom.shp')
print (gdf)
# Out:
#                   Concelho                                           geometry
# 0   SANTA CRUZ DA GRACIOSA  POLYGON ((417875.553 4319572.499, 417872.553 4...
# 1        ANGRA DO HEROÍSMO  POLYGON ((487869.941 4277345.424, 487861.501 4...
# 2                    LAGOA  POLYGON ((633096.478 4178286.484, 633097.838 4...
# 3            LAJES DO PICO  POLYGON ((396137.449 4255275.487, 396345.977 4...
# 4            VILA DO PORTO  POLYGON ((673889.689 4094895.135, 673890.319 4...
# 5         PRAIA DA VITÓRIA  POLYGON ((496298.161 4283113.991, 496298.241 4...
# 6            PONTA DELGADA  POLYGON ((616518.301 4177118.287, 616513.261 4...
# 7                    HORTA  POLYGON ((358277.853 4266306.052, 358270.723 4...
# 8                    VELAS  POLYGON ((408426.644 4277271.006, 408406.584 4...
# 9                    CORVO  POLYGON ((147072.757 4399142.126, 147070.069 4...
# 10    CALHETA DE SÃO JORGE  POLYGON ((429195.192 4270200.484, 429211.782 4...
# 11        LAJES DAS FLORES  POLYGON ((135499.418 4366510.163, 135489.747 4...
# 12          RIBEIRA GRANDE  POLYGON ((623483.538 4186657.648, 623494.608 4...
# 13   SANTA CRUZ DAS FLORES  POLYGON ((143263.417 4373293.062, 143263.197 4...
# 14       SÃO ROQUE DO PICO  POLYGON ((402118.004 4256386.502, 402021.043 4...
# 15                MADALENA  POLYGON ((380935.542 4252446.942, 380931.792 4...
# 16                NORDESTE  POLYGON ((663174.109 4189992.903, 663176.349 4...
# 17                POVOAÇÃO  POLYGON ((660000.111 4178762.844, 659993.991 4...
# 18    VILA FRANCA DO CAMPO  MULTIPOLYGON (((637249.017 4174245.849, 637262...

# %%
gdf.head()
# Out:
#                  Concelho                                           geometry
# 0  SANTA CRUZ DA GRACIOSA  POLYGON ((417875.553 4319572.499, 417872.553 4...
# 1       ANGRA DO HEROÍSMO  POLYGON ((487869.941 4277345.424, 487861.501 4...
# 2                   LAGOA  POLYGON ((633096.478 4178286.484, 633097.838 4...
# 3           LAJES DO PICO  POLYGON ((396137.449 4255275.487, 396345.977 4...
# 4           VILA DO PORTO  POLYGON ((673889.689 4094895.135, 673890.319 4...

# %%
# testing out the data to see how it looks with a cmap
plot = gdf.plot(column='Concelho', cmap='OrRd', figsize=(14, 14))

fig = plot.get_figure()

# %%
# load in new csv file
df = pd.read_csv("/content/drive/My Drive/SIG/covid19_acores.csv", header=0, encoding="utf-8")

df.head()
# Out:
#         concelho  24/03/2020  25/03/2020  ...  06/05/2020  07/05/2020  08/05/2020
# 0  VILA DO PORTO         NaN         NaN  ...         NaN         NaN         NaN
# 1          LAGOA         NaN         NaN  ...         NaN         NaN         NaN
# 2       NORDESTE         NaN         NaN  ...        14.0        14.0        14.0
# 3  PONTA DELGADA         NaN         NaN  ...         8.0         8.0         8.0
# 4       POVOAÇÃO         NaN         NaN  ...         NaN         NaN         NaN
#
# [5 rows x 47 columns]

# %%
# filter to include only data labeled as 'Violence Against the Person'
#filtered = df['distrito'] == 'AVEIRO'

#covid19 = df[filtered]

#covid19

df3 = df.groupby('concelho')

df3.head()
# Out:
#                   concelho  24/03/2020  ...  07/05/2020  08/05/2020
# 0            VILA DO PORTO         NaN  ...         NaN         NaN
# 1                    LAGOA         NaN  ...         NaN         NaN
# 2                 NORDESTE         NaN  ...        14.0        14.0
# 3            PONTA DELGADA         NaN  ...         8.0         8.0
# 4                 POVOAÇÃO         NaN  ...         NaN         NaN
# 5           RIBEIRA GRANDE         NaN  ...         NaN         NaN
# 6     VILA FRANCA DO CAMPO         NaN  ...         NaN         NaN
# 7        ANGRA DO HEROÍSMO         NaN  ...         NaN         NaN
# 8         PRAIA DA VITÓRIA         NaN  ...         7.0         7.0
# 9   SANTA CRUZ DA GRACIOSA         NaN  ...         NaN         NaN
# 10    CALHETA DE SÃO JORGE         NaN  ...         NaN         NaN
# 11                   VELAS         NaN  ...         5.0         5.0
# 12           LAJES DO PICO         NaN  ...         NaN         NaN
# 13                MADALENA         NaN  ...         5.0         5.0
# 14       SÃO ROQUE DO PICO         NaN  ...         3.0         3.0
# 15                   HORTA         NaN  ...         6.0         6.0
# 16        LAJES DAS FLORES         NaN  ...         NaN         NaN
# 17   SANTA CRUZ DAS FLORES         NaN  ...         NaN         NaN
#
# [18 rows x 47 columns]

# %%
df1 = df.rename(columns={'24/03/2020': '24-03-2020', '25/03/2020': '25-03-2020',
                  '26/03/2020': '26-03-2020', '27/03/2020': '27-03-2020', 
                   '28/03/2020': '28-03-2020', '29/03/2020': '29-03-2020',
                  '30/03/2020': '30-03-2020', '31/03/2020': '31-03-2020',
                  '01/04/2020': '01-04-2020', '02/04/2020':'02-04-2020',
                   '03/04/2020':'03-04-2020', '04/04/2020': '04-04-2020', 
                  '05/04/2020':'05-04-2020', '06/04/2020':'06-04-2020', 
                   '07/04/2020': '07-04-2020', '08/04/2020': '08-04-2020', 
                   '09/04/2020': '09-04-2020', '10/04/2020':'10-04-2020',
                  '11/04/2020':'11-04-2020', '12/04/2020':'12-04-2020', 
                  '13/04/2020':'13-04-2020', '14/04/2020':'14-04-2020',
                  '15/04/2020':'15-04-2020', '16/04/2020':'16-04-2020',
                  '17/04/2020':'17-04-2020', '18/04/2020':'18-04-2020',
                  '19/04/2020':'19-04-2020', '20/04/2020':'20-04-2020', 
                  '21/04/2020':'21-04-2020', '22/04/2020':'22-04-2020',
                  '23/04/2020':'23-04-2020', '24/04/2020':'24-04-2020',
                  '25/04/2020':'25-04-2020', '26/04/2020':'26-04-2020',
                  '27/04/2020':'27-04-2020', '28/04/2020':'28-04-2020',
                  '29/04/2020':'29-04-2020', '30/04/2020':'30-04-2020',
                  '01/05/2020':'01-05-2020', '02/05/2020':'02-05-2020', 
                  '03/05/2020':'03-05-2020', '04/05/2020':'04-05-2020',
                  '06/05/2020':'06-05-2020', '05/05/2020':'05-05-2020',
                  '07/05/2020':'07-05-2020', '08/05/2020':'08-05-2020'})

# %%
df1.fillna(0)
# Out:
#                   concelho  24-03-2020  ...  07-05-2020  08-05-2020
# 0            VILA DO PORTO         0.0  ...         0.0         0.0
# 1                    LAGOA         0.0  ...         0.0         0.0
# 2                 NORDESTE         0.0  ...        14.0        14.0
# 3            PONTA DELGADA         0.0  ...         8.0         8.0
# 4                 POVOAÇÃO         0.0  ...         0.0         0.0
# 5           RIBEIRA GRANDE         0.0  ...         0.0         0.0
# 6     VILA FRANCA DO CAMPO         0.0  ...         0.0         0.0
# 7        ANGRA DO HEROÍSMO         0.0  ...         0.0         0.0
# 8         PRAIA DA VITÓRIA         0.0  ...         7.0         7.0
# 9   SANTA CRUZ DA GRACIOSA         0.0  ...         0.0         0.0
# 10    CALHETA DE SÃO JORGE         0.0  ...         0.0         0.0
# 11                   VELAS         0.0  ...         5.0         5.0
# 12           LAJES DO PICO         0.0  ...         0.0         0.0
# 13                MADALENA         0.0  ...         5.0         5.0
# 14       SÃO ROQUE DO PICO         0.0  ...         3.0         3.0
# 15                   HORTA         0.0  ...         6.0         6.0
# 16        LAJES DAS FLORES         0.0  ...         0.0         0.0
# 17   SANTA CRUZ DAS FLORES         0.0  ...         0.0         0.0
#
# [18 rows x 47 columns]

# %%
# then we need to melt the df so it's in tidy format. reshape the table to keep the columns borough, category, year (as variable) and value
melted = pd.melt(df1,  id_vars=['concelho'], var_name='data', value_name='nofcases')
melted = melted.fillna(0)

# %%
melted.head()
# Out:
#         concelho        data  nofcases
# 0  VILA DO PORTO  24-03-2020       0.0
# 1          LAGOA  24-03-2020       0.0
# 2       NORDESTE  24-03-2020       0.0
# 3  PONTA DELGADA  24-03-2020       0.0
# 4       POVOAÇÃO  24-03-2020       0.0

# %%
df2 = melted.groupby('concelho')

df2.head()
# Out:
#                  concelho        data  nofcases
# 0           VILA DO PORTO  24-03-2020       0.0
# 1                   LAGOA  24-03-2020       0.0
# 2                NORDESTE  24-03-2020       0.0
# 3           PONTA DELGADA  24-03-2020       0.0
# 4                POVOAÇÃO  24-03-2020       0.0
# ..                    ...         ...       ...
# 85               MADALENA  28-03-2020       3.0
# 86      SÃO ROQUE DO PICO  28-03-2020       0.0
# 87                  HORTA  28-03-2020       4.0
# 88       LAJES DAS FLORES  28-03-2020       0.0
# 89  SANTA CRUZ DAS FLORES  28-03-2020       0.0
#
# [90 rows x 3 columns]

# %%
# then let's pivot the dataframe to add on the column 'major_category' and add up the values for each borough by year
covid = melted.pivot_table(values='nofcases', index=['concelho'], columns='data', aggfunc=np.sum)
covid.columns = covid.columns.get_level_values(0)
covid.head()
# Out:
# data                  01-04-2020  01-05-2020  ...  30-04-2020  31-03-2020
# concelho                                      ...
# ANGRA DO HEROÍSMO            0.0         0.0  ...         0.0         0.0
# CALHETA DE SÃO JORGE         0.0         0.0  ...         0.0         0.0
# HORTA                        6.0         6.0  ...         6.0         6.0
# LAGOA                        0.0         0.0  ...         0.0         0.0
# LAJES DAS FLORES             0.0         0.0  ...         0.0         0.0
#
# [5 rows x 46 columns]

# %%
# join the geodataframe with the cleaned up csv dataframe
merged1 = gdf.set_index('Concelho').join(covid)

merged1 = merged1.reindex(merged1.index.rename('Concelho'))

merged1.max
# Out:
# <bound method DataFrame.max of                                                                  geometry  ...  31-03-2020
# Concelho                                                                   ...
# SANTA CRUZ DA GRACIOSA  POLYGON ((417875.553 4319572.499, 417872.553 4...  ...         0.0
# ANGRA DO HEROÍSMO       POLYGON ((487869.941 4277345.424, 487861.501 4...  ...         0.0
# LAGOA                   POLYGON ((633096.478 4178286.484, 633097.838 4...  ...         0.0
# LAJES DO PICO           POLYGON ((396137.449 4255275.487, 396345.977 4...  ...         0.0
# VILA DO PORTO           POLYGON ((673889.689 4094895.135, 673890.319 4...  ...         0.0
# PRAIA DA VITÓRIA        POLYGON ((496298.161 4283113.991, 496298.241 4...  ...         5.0
# PONTA DELGADA           POLYGON ((616518.301 4177118.287, 616513.261 4...  ...         0.0
# HORTA                   POLYGON ((358277.853 4266306.052, 358270.723 4...  ...         6.0
# VELAS                   POLYGON ((408426.644 4277271.006, 408406.584 4...  ...         5.0
# CORVO                   POLYGON ((147072.757 4399142.126, 147070.069 4...  ...         NaN
# CALHETA DE SÃO JORGE    POLYGON ((429195.192 4270200.484, 429211.782 4...  ...         0.0
# LAJES DAS FLORES        POLYGON ((135499.418 4366510.163, 135489.747 4...  ...         0.0
# RIBEIRA GRANDE          POLYGON ((623483.538 4186657.648, 623494.608 4...  ...         0.0
# SANTA CRUZ DAS FLORES   POLYGON ((143263.417 4373293.062, 143263.197 4...  ...         0.0
# SÃO ROQUE DO PICO       POLYGON ((402118.004 4256386.502, 402021.043 4...  ...         3.0
# MADALENA                POLYGON ((380935.542 4252446.942, 380931.792 4...  ...         3.0
# NORDESTE                POLYGON ((663174.109 4189992.903, 663176.349 4...  ...         0.0
# POVOAÇÃO                POLYGON ((660000.111 4178762.844, 659993.991 4...  ...         0.0
# VILA FRANCA DO CAMPO    MULTIPOLYGON (((637249.017 4174245.849, 637262...  ...         0.0
#
# [19 rows x 47 columns]>

# %%
# CREATE A LOOP TO MAKE MULTIPLE MAPS WITH YEAR ANNOTATIONS

# save all the maps in the charts folder
output_path = '/content/drive/My Drive/SIG/charts/maps_acores'

# counter for the for loop
i = 0

# list of days (which are the column names at the moment)
list_of_days = ['24-03-2020', '25-03-2020',
                  '26-03-2020', '27-03-2020', 
                  '28-03-2020', '29-03-2020',
                 '30-03-2020', '31-03-2020',
                  '01-04-2020', '02-04-2020',
                  '03-04-2020',  '04-04-2020', 
                  '05-04-2020', '06-04-2020', 
                   '07-04-2020', '08-04-2020', 
                   '09-04-2020', '10-04-2020',
                 '11-04-2020', '12-04-2020', 
                  '13-04-2020', '14-04-2020',
                  '15-04-2020', '16-04-2020',
                 '17-04-2020', '18-04-2020',
                 '19-04-2020', '20-04-2020', 
                  '21-04-2020', '22-04-2020',
                 '23-04-2020', '24-04-2020', '25-04-2020', '26-04-2020', '27-04-2020', '28-04-2020', '29-04-2020', 
                '30-04-2020', '01-05-2020',
                '02-05-2020', '03-05-2020', '04-05-2020', '05-05-2020', '06-05-2020', '07-05-2020', '08-05-2020']

# set the min and max range for the choropleth map
vmin, vmax = 0, 15

# start the for loop to create one map per year
for day in list_of_days:
    
    # create map
    fig = merged1.plot(column=day, cmap='Blues', figsize=(14,14), linewidth=0.5, edgecolor='0.8', vmin=0, vmax=15, legend=True) 
    
    # UDPATE: added plt.Normalize to keep the legend range the same for all maps
    
    # remove axis of chart
    fig.axis('off')
    
    # add a title
    fig.set_title('COVID-19 nos Açores', \
              fontdict={'fontsize': '15',
                         'fontweight' : '3'})
    
    # create an annotation for the day
    #only_day = (datetime.strptime(day, '%Y-%m-%d'))
    
    # position the annotation to the bottom left
    fig.annotate(day,
            xy=(0.1, .2), xycoords='figure fraction',
            horizontalalignment='left', verticalalignment='top',
            fontsize=15)
    
    # this will save the figure as a high-res png in the output path. you can also save as svg if you prefer.
    filepath = os.path.join(output_path, day+'_covid.png')
    only_day = (datetime.strptime(day, '%d-%m-%Y')+ timedelta(days=1)).strftime('%d-%m-%Y')
    chart = fig.get_figure()
    chart.savefig(filepath, dpi=300)
# Out:
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# /usr/local/lib/python3.6/dist-packages/geopandas/plotting.py:525: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
